# %%
# Paso 1: Instalación de paquetes necesarios
if (!require("lightgbm")) install.packages("lightgbm")
if (!require("mlrMBO")) install.packages("mlrMBO")
if (!require("data.table")) install.packages("data.table")

library(lightgbm)
library(mlrMBO)
library(data.table)
library(parallel)
library(smoof)
library(mlr)
library(ggplot2)

# %%
# Paso 2: Análisis exploratorio simple
iris_dt <- as.data.table(iris)
print(iris_dt[, .N, by = Species])
# Out:
#       Species     N
#        <fctr> <int>
# 1:     setosa    50
# 2: versicolor    50
# 3:  virginica    50

# %%
# Paso 3: Dataset sin duplicar (baseline)
iris_base <- copy(iris_dt)
iris_base[, target := ifelse(Species == "virginica", 1L, 0L)]
iris_base[, Species := NULL]

# %%
# Paso 4: Dataset duplicado (con ruido negativo)
iris_dup <- copy(iris_dt)
iris_dup[, target := ifelse(Species == "virginica", 1L, 0L)]
iris_pos <- iris_dup[target == 1L]
iris_neg_copies <- copy(iris_pos)[, target := 0L]
iris_augmented <- rbindlist(list(iris_dup, iris_neg_copies))
iris_augmented[, Species := NULL]

# %%
start_time <- Sys.time()

# Paso 5: Función de entrenamiento y evaluación
train_evaluate <- function(data, seed = 123, iters = 10) {
  set.seed(seed)
  idx_train <- sample(1:nrow(data), 0.7 * nrow(data))
  train <- data[idx_train]
  test <- data[-idx_train]

  dtrain <- lgb.Dataset(data = data.matrix(train[, !"target", with = FALSE]), label = train$target)

  param_base <- list(objective = "binary",
                     metric = "auc",
                     verbosity = -1,
                     feature_pre_filter = FALSE)

  ps <- makeParamSet(
    makeNumericParam("learning_rate", lower = 0.01, upper = 0.2),
    makeIntegerParam("num_leaves", lower = 10L, upper = 100L),
    makeIntegerParam("min_data_in_leaf", lower = 5L, upper = 50L)
  )

  obj_fun <- makeSingleObjectiveFunction(
    fn = function(x) {
      x <- as.list(x)
      param <- modifyList(param_base, x)
      cv <- suppressMessages(lgb.cv(params = param,
                   data = dtrain,
                   nfold = 3,
                   nrounds = 100,
                   early_stopping_rounds = 10,
                   verbose = -1))
      return(max(unlist(cv$record_evals$valid$auc$eval)))
    },
    par.set = ps,
    minimize = FALSE
  )

  ctrl <- makeMBOControl()
  ctrl <- setMBOControlTermination(ctrl, iters = iters)
  ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())
  surrogate <- makeLearner("regr.km", predict.type = "se")

  run <- suppressMessages(mbo(obj_fun, learner = surrogate, control = ctrl))

  dbest <- suppressMessages(lgb.train(params = modifyList(param_base, as.list(run$x)),
                     data = dtrain,
                     nrounds = 100))

  y_pred <- predict(dbest, data.matrix(test[, !"target", with = FALSE]))
  if (!require("pROC")) install.packages("pROC")
  library(pROC)
  auc_final <- auc(test$target, y_pred)

  list(run = run, auc = auc_final, predictions = y_pred, test = test)
}

# %%
# Paso 6: Ejecutar ambos experimentos
res_base <- train_evaluate(iris_base, iters = 20)
res_augm <- train_evaluate(iris_augmented, iters = 20)
# Out:
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3634012 164 88
#   - best initial criterion value(s) :  8.538131
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -8.5381  |proj g|=     0.084911
# At iterate     1  f =      -8.5576  |proj g|=      0.081257
# At iterate     2  f =      -8.6204  |proj g|=       0.04403
# At iterate     3  f =      -8.6506  |proj g|=     0.0074206
# At iterate     4  f =      -8.6516  |proj g|=      0.002045
# At iterate     5  f =      -8.6517  |proj g|=     0.0020186
# At iterate     6  f =      -8.6517  |proj g|=     0.0020076
# At iterate     7  f =      -8.6517  |proj g|=     0.0019586
# At iterate     8  f =      -8.6519  |proj g|=     0.0025045
# At iterate     9  f =      -8.6522  |proj g|=     0.0042592
# At iterate    10  f =      -8.6528  |proj g|=      0.006145
# At iterate    11  f =      -8.6538  |proj g|=     0.0069973
# At iterate    12  f =      -8.6548  |proj g|=     0.0051241
# At iterate    13  f =      -8.6553  |proj g|=     0.0017098
# At iterate    14  f =      -8.6553  |proj g|=    0.00011914
# At iterate    15  f =      -8.6553  |proj g|=    1.1258e-05
# At iterate    16  f =      -8.6553  |proj g|=    1.9809e-06
# At iterate    17  f =      -8.6553  |proj g|=    1.2061e-07
#
# iterations 17
# function evaluations 18
# segments explored during Cauchy searches 18
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.20612e-07
# final function value -8.65534
#
# F = -8.65534
# final  value -8.655340
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3634012 164 88
#   - best initial criterion value(s) :  7.209885
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -7.2099  |proj g|=      0.75428
# At iterate     1  f =      -8.2175  |proj g|=       0.53013
# At iterate     2  f =      -8.5055  |proj g|=       0.33657
# At iterate     3  f =      -8.7541  |proj g|=       0.10926
# At iterate     4  f =      -8.7944  |proj g|=      0.037498
# At iterate     5  f =      -8.8009  |proj g|=     0.0077776
# At iterate     6  f =      -8.8012  |proj g|=     0.0073522
# At iterate     7  f =      -8.8012  |proj g|=     0.0073981
# At iterate     8  f =      -8.8013  |proj g|=     0.0074536
# At iterate     9  f =      -8.8014  |proj g|=     0.0075529
# At iterate    10  f =      -8.8016  |proj g|=     0.0077148
# At iterate    11  f =      -8.8022  |proj g|=      0.010875
# At iterate    12  f =      -8.8037  |proj g|=      0.018358
# At iterate    13  f =      -8.8077  |proj g|=      0.030029
# At iterate    14  f =      -8.8209  |proj g|=      0.047695
# At iterate    15  f =      -9.1979  |proj g|=      0.073169
# At iterate    16  f =      -9.2012  |proj g|=      0.078996
# At iterate    17  f =      -9.4027  |proj g|=      0.085483
# At iterate    18  f =      -9.5969  |proj g|=      0.024439
# At iterate    19  f =      -9.6046  |proj g|=       0.01515
# At iterate    20  f =       -9.607  |proj g|=     0.0019597
# At iterate    21  f =      -9.6072  |proj g|=    0.00023478
# At iterate    22  f =      -9.6072  |proj g|=    1.2497e-05
# At iterate    23  f =      -9.6072  |proj g|=    1.6582e-08
#
# iterations 23
# function evaluations 32
# segments explored during Cauchy searches 24
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.65825e-08
# final function value -9.60718
#
# F = -9.60718
# final  value -9.607178
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3634012 164 88
#   - best initial criterion value(s) :  7.627615
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -7.6276  |proj g|=      0.17415
# At iterate     1  f =      -8.1468  |proj g|=       0.14931
# At iterate     2  f =      -10.406  |proj g|=        0.1273
# At iterate     3  f =      -10.819  |proj g|=      0.096275
# At iterate     4  f =      -10.966  |proj g|=      0.030314
# At iterate     5  f =       -10.97  |proj g|=      0.025002
# At iterate     6  f =      -10.975  |proj g|=     0.0025115
# At iterate     7  f =      -10.975  |proj g|=     0.0011714
# At iterate     8  f =      -10.975  |proj g|=     0.0011666
# At iterate     9  f =      -10.975  |proj g|=     0.0011619
# At iterate    10  f =      -10.975  |proj g|=     0.0011491
# At iterate    11  f =      -10.975  |proj g|=     0.0011893
# At iterate    12  f =      -10.975  |proj g|=     0.0021434
# At iterate    13  f =      -10.975  |proj g|=     0.0035129
# At iterate    14  f =      -10.976  |proj g|=     0.0051281
# At iterate    15  f =      -10.976  |proj g|=     0.0058791
# At iterate    16  f =      -10.976  |proj g|=     0.0042283
# At iterate    17  f =      -10.976  |proj g|=     0.0015365
# At iterate    18  f =      -10.976  |proj g|=    0.00016975
# At iterate    19  f =      -10.976  |proj g|=    8.9394e-06
# At iterate    20  f =      -10.976  |proj g|=    1.7056e-06
#
# iterations 20
# function evaluations 30
# segments explored during Cauchy searches 21
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.70564e-06
# final function value -10.9764
#
# F = -10.9764
# final  value -10.976373
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3702371 164 88
#   - best initial criterion value(s) :  12.10277
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -12.103  |proj g|=     0.085504
# At iterate     1  f =      -12.405  |proj g|=       0.11994
# At iterate     2  f =      -12.484  |proj g|=       0.10125
# At iterate     3  f =      -12.606  |proj g|=      0.032496
# At iterate     4  f =      -12.613  |proj g|=      0.016619
# At iterate     5  f =      -12.615  |proj g|=     0.0033033
# At iterate     6  f =      -12.615  |proj g|=     0.0032712
# At iterate     7  f =      -12.615  |proj g|=      0.003262
# At iterate     8  f =      -12.615  |proj g|=     0.0032235
# At iterate     9  f =      -12.615  |proj g|=     0.0033942
# At iterate    10  f =      -12.616  |proj g|=     0.0062329
# At iterate    11  f =      -12.616  |proj g|=       0.01034
# At iterate    12  f =      -12.618  |proj g|=      0.015523
# At iterate    13  f =      -12.621  |proj g|=      0.018637
# At iterate    14  f =      -12.624  |proj g|=      0.014107
# At iterate    15  f =      -12.625  |proj g|=     0.0055384
# At iterate    16  f =      -12.625  |proj g|=    0.00066743
# At iterate    17  f =      -12.625  |proj g|=    1.3597e-05
# At iterate    18  f =      -12.625  |proj g|=    8.1853e-07
# At iterate    19  f =      -12.625  |proj g|=    5.8432e-08
#
# iterations 19
# function evaluations 24
# segments explored during Cauchy searches 20
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 5.84316e-08
# final function value -12.6253
#
# F = -12.6253
# final  value -12.625250
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3702371 164 90
#   - best initial criterion value(s) :  11.61898
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -11.619  |proj g|=      0.65687
# At iterate     1  f =      -12.338  |proj g|=       0.55242
# At iterate     2  f =       -13.14  |proj g|=       0.23408
# At iterate     3  f =      -13.379  |proj g|=      0.073715
# At iterate     4  f =      -13.419  |proj g|=      0.031797
# At iterate     5  f =      -13.424  |proj g|=      0.031455
# At iterate     6  f =      -13.425  |proj g|=      0.031321
# At iterate     7  f =      -13.427  |proj g|=      0.031043
# At iterate     8  f =      -13.432  |proj g|=      0.030419
# At iterate     9  f =      -13.444  |proj g|=      0.045578
# At iterate    10  f =      -13.472  |proj g|=      0.065871
# At iterate    11  f =      -13.527  |proj g|=      0.085221
# At iterate    12  f =      -13.613  |proj g|=      0.093238
# At iterate    13  f =      -13.746  |proj g|=      0.062579
# At iterate    14  f =        -13.8  |proj g|=     0.0066302
# At iterate    15  f =      -13.801  |proj g|=    0.00024698
# At iterate    16  f =      -13.801  |proj g|=    8.6054e-05
# At iterate    17  f =      -13.801  |proj g|=    6.6607e-05
# At iterate    18  f =      -13.801  |proj g|=    1.7636e-05
# At iterate    19  f =      -13.801  |proj g|=    1.1809e-06
#
# iterations 19
# function evaluations 20
# segments explored during Cauchy searches 20
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.18093e-06
# final function value -13.8006
#
# F = -13.8006
# final  value -13.800613
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3702371 178 90
#   - best initial criterion value(s) :  12.89218
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -12.892  |proj g|=      0.19997
# At iterate     1  f =      -14.207  |proj g|=       0.17948
# At iterate     2  f =       -15.06  |proj g|=         0.115
# At iterate     3  f =      -15.205  |proj g|=      0.027424
# At iterate     4  f =      -15.209  |proj g|=      0.016255
# At iterate     5  f =      -15.211  |proj g|=      0.016203
# At iterate     6  f =      -15.214  |proj g|=      0.016047
# At iterate     7  f =      -15.223  |proj g|=      0.028407
# At iterate     8  f =      -15.249  |proj g|=      0.057193
# At iterate     9  f =      -15.304  |proj g|=      0.090138
# At iterate    10  f =      -15.384  |proj g|=      0.092845
# At iterate    11  f =      -15.429  |proj g|=      0.045017
# At iterate    12  f =      -15.441  |proj g|=     0.0094279
# At iterate    13  f =      -15.441  |proj g|=    0.00077645
# At iterate    14  f =      -15.441  |proj g|=    1.9254e-05
# At iterate    15  f =      -15.441  |proj g|=    2.3514e-07
#
# iterations 15
# function evaluations 22
# segments explored during Cauchy searches 16
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 2.35137e-07
# final function value -15.4412
#
# F = -15.4412
# final  value -15.441188
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3702371 178 90
#   - best initial criterion value(s) :  16.29353
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -16.294  |proj g|=      0.12971
# At iterate     1  f =      -17.259  |proj g|=      0.060362
# At iterate     2  f =      -17.274  |proj g|=       0.03842
# At iterate     3  f =      -17.287  |proj g|=      0.011239
# At iterate     4  f =      -17.287  |proj g|=      0.011287
# At iterate     5  f =      -17.289  |proj g|=      0.011476
# At iterate     6  f =      -17.294  |proj g|=      0.022074
# At iterate     7  f =      -17.306  |proj g|=      0.038835
# At iterate     8  f =      -17.334  |proj g|=        0.0571
# At iterate     9  f =      -17.371  |proj g|=      0.064593
# At iterate    10  f =      -17.402  |proj g|=      0.049008
# At iterate    11  f =      -17.421  |proj g|=      0.011107
# At iterate    12  f =      -17.423  |proj g|=    0.00090412
# At iterate    13  f =      -17.423  |proj g|=    1.0113e-05
# At iterate    14  f =      -17.423  |proj g|=    2.4573e-08
#
# iterations 14
# function evaluations 19
# segments explored during Cauchy searches 15
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 2.45732e-08
# final function value -17.4231
#
# F = -17.4231
# final  value -17.423058
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3702416 178 90
#   - best initial criterion value(s) :  17.7173
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -17.717  |proj g|=      0.16316
# At iterate     1  f =      -18.818  |proj g|=       0.15936
# At iterate     2  f =       -18.88  |proj g|=       0.11556
# At iterate     3  f =      -18.958  |proj g|=      0.017052
# At iterate     4  f =      -18.961  |proj g|=      0.016749
# At iterate     5  f =      -18.963  |proj g|=      0.016505
# At iterate     6  f =       -18.97  |proj g|=      0.020797
# At iterate     7  f =      -18.985  |proj g|=      0.038343
# At iterate     8  f =      -19.019  |proj g|=      0.055725
# At iterate     9  f =      -19.063  |proj g|=      0.058622
# At iterate    10  f =      -19.098  |proj g|=      0.037882
# At iterate    11  f =      -19.109  |proj g|=     0.0087287
# At iterate    12  f =       -19.11  |proj g|=     0.0012185
# At iterate    13  f =       -19.11  |proj g|=    0.00016492
# At iterate    14  f =       -19.11  |proj g|=    3.3928e-05
# At iterate    15  f =       -19.11  |proj g|=    2.1913e-06
#
# iterations 15
# function evaluations 19
# segments explored during Cauchy searches 16
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 2.19133e-06
# final function value -19.1101
#
# F = -19.1101
# final  value -19.110120
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3702416 178 90
#   - best initial criterion value(s) :  19.98721
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -19.987  |proj g|=      0.24049
# At iterate     1  f =      -20.068  |proj g|=       0.23723
# At iterate     2  f =      -20.688  |proj g|=      0.047333
# At iterate     3  f =      -20.694  |proj g|=      0.046529
# At iterate     4  f =      -20.704  |proj g|=      0.031576
# At iterate     5  f =      -20.722  |proj g|=      0.031048
# At iterate     6  f =      -20.858  |proj g|=       0.09118
# At iterate     7  f =      -20.998  |proj g|=       0.10354
# At iterate     8  f =      -21.129  |proj g|=      0.046001
# At iterate     9  f =      -21.146  |proj g|=      0.010096
# At iterate    10  f =      -21.147  |proj g|=     0.0017399
# At iterate    11  f =      -21.147  |proj g|=    0.00033197
# At iterate    12  f =      -21.147  |proj g|=    3.5575e-05
# At iterate    13  f =      -21.147  |proj g|=    1.7426e-05
# At iterate    14  f =      -21.147  |proj g|=    1.4088e-06
#
# iterations 14
# function evaluations 18
# segments explored during Cauchy searches 15
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.40878e-06
# final function value -21.1469
#
# F = -21.1469
# final  value -21.146927
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3702416 178 90
#   - best initial criterion value(s) :  22.63451
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -22.635  |proj g|=     0.078698
# At iterate     1  f =      -23.423  |proj g|=      0.028536
# At iterate     2  f =      -23.425  |proj g|=      0.023636
# At iterate     3  f =      -23.429  |proj g|=      0.010332
# At iterate     4  f =      -23.448  |proj g|=      0.028579
# At iterate     5  f =      -23.504  |proj g|=      0.055107
# At iterate     6  f =      -23.536  |proj g|=       0.02986
# At iterate     7  f =       -23.54  |proj g|=     0.0074498
# At iterate     8  f =       -23.54  |proj g|=     0.0002008
# At iterate     9  f =       -23.54  |proj g|=    1.0692e-06
# At iterate    10  f =       -23.54  |proj g|=    6.9915e-08
#
# iterations 10
# function evaluations 17
# segments explored during Cauchy searches 11
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 6.99152e-08
# final function value -23.5404
#
# F = -23.5404
# final  value -23.540433
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3702416 178 90
#   - best initial criterion value(s) :  20.52386
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -20.524  |proj g|=      0.20608
# At iterate     1  f =      -23.228  |proj g|=       0.12055
# At iterate     2  f =      -23.272  |proj g|=      0.075464
# At iterate     3  f =      -23.299  |proj g|=      0.039164
# At iterate     4  f =      -23.302  |proj g|=       0.03799
# At iterate     5  f =      -23.309  |proj g|=      0.036518
# At iterate     6  f =      -23.331  |proj g|=      0.044203
# At iterate     7  f =      -23.407  |proj g|=       0.10687
# At iterate     8  f =      -23.532  |proj g|=        0.1621
# At iterate     9  f =       -23.79  |proj g|=       0.19522
# At iterate    10  f =      -24.241  |proj g|=     0.0066395
# At iterate    11  f =      -24.314  |proj g|=       0.17865
# At iterate    12  f =      -24.495  |proj g|=       0.32814
# At iterate    13  f =      -24.576  |proj g|=      0.032911
# At iterate    14  f =      -24.577  |proj g|=      0.005169
# At iterate    15  f =      -24.577  |proj g|=    0.00010698
# At iterate    16  f =      -24.577  |proj g|=     3.593e-07
#
# iterations 16
# function evaluations 23
# segments explored during Cauchy searches 17
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 3.59301e-07
# final function value -24.5767
#
# F = -24.5767
# final  value -24.576679
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3702416 178 90
#   - best initial criterion value(s) :  22.86832
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -22.868  |proj g|=      0.48398
# At iterate     1  f =      -25.975  |proj g|=       0.62846
# At iterate     2  f =      -26.199  |proj g|=       0.55598
# At iterate     3  f =      -26.682  |proj g|=       0.21462
# At iterate     4  f =      -26.722  |proj g|=        0.1298
# At iterate     5  f =      -26.738  |proj g|=      0.015691
# At iterate     6  f =      -26.738  |proj g|=     0.0034419
# At iterate     7  f =      -26.738  |proj g|=      0.003478
# At iterate     8  f =      -26.738  |proj g|=     0.0075089
# At iterate     9  f =      -26.739  |proj g|=      0.016151
# At iterate    10  f =       -26.74  |proj g|=      0.031895
# At iterate    11  f =      -26.742  |proj g|=      0.057198
# At iterate    12  f =      -26.749  |proj g|=       0.10191
# At iterate    13  f =      -26.764  |proj g|=       0.18489
# At iterate    14  f =      -26.796  |proj g|=       0.26742
# At iterate    15  f =      -26.824  |proj g|=       0.16987
# At iterate    16  f =      -26.845  |proj g|=      0.016249
# At iterate    17  f =      -26.845  |proj g|=     0.0011542
# At iterate    18  f =      -26.845  |proj g|=    8.7854e-06
# At iterate    19  f =      -26.845  |proj g|=    4.8055e-09
#
# iterations 19
# function evaluations 22
# segments explored during Cauchy searches 20
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 4.80546e-09
# final function value -26.8448
#
# F = -26.8448
# final  value -26.844776
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3702416 180 90
#   - best initial criterion value(s) :  26.53437
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -26.534  |proj g|=       1.2623
# At iterate     1  f =      -28.767  |proj g|=       0.48727
# At iterate     2  f =      -29.018  |proj g|=       0.07603
# At iterate     3  f =      -29.025  |proj g|=      0.014723
# At iterate     4  f =      -29.026  |proj g|=     0.0061257
# At iterate     5  f =      -29.026  |proj g|=     0.0060288
# At iterate     6  f =      -29.027  |proj g|=      0.016501
# At iterate     7  f =      -29.029  |proj g|=      0.032034
# At iterate     8  f =      -29.034  |proj g|=      0.056834
# At iterate     9  f =      -29.044  |proj g|=      0.084317
# At iterate    10  f =      -29.065  |proj g|=       0.10072
# At iterate    11  f =      -29.105  |proj g|=      0.047069
# At iterate    12  f =      -29.131  |proj g|=      0.050112
# At iterate    13  f =      -29.157  |proj g|=       0.27658
# At iterate    14  f =      -29.188  |proj g|=       0.17279
# At iterate    15  f =      -29.209  |proj g|=      0.017893
# At iterate    16  f =       -29.21  |proj g|=     0.0013601
# At iterate    17  f =       -29.21  |proj g|=    1.2028e-05
# At iterate    18  f =       -29.21  |proj g|=     8.191e-09
#
# iterations 18
# function evaluations 19
# segments explored during Cauchy searches 19
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 8.19103e-09
# final function value -29.2096
#
# F = -29.2096
# final  value -29.209574
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3702416 180 90
#   - best initial criterion value(s) :  29.41197
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -29.412  |proj g|=      0.13066
# At iterate     1  f =      -31.129  |proj g|=      0.060821
# At iterate     2  f =       -31.13  |proj g|=      0.051272
# At iterate     3  f =      -31.135  |proj g|=      0.010386
# At iterate     4  f =      -31.136  |proj g|=      0.010249
# At iterate     5  f =      -31.137  |proj g|=      0.018179
# At iterate     6  f =       -31.14  |proj g|=      0.035859
# At iterate     7  f =      -31.148  |proj g|=      0.065527
# At iterate     8  f =      -31.166  |proj g|=       0.10123
# At iterate     9  f =      -31.205  |proj g|=       0.13163
# At iterate    10  f =      -31.276  |proj g|=       0.10261
# At iterate    11  f =      -31.328  |proj g|=       0.05074
# At iterate    12  f =      -31.347  |proj g|=       0.13476
# At iterate    13  f =      -31.379  |proj g|=       0.26867
# At iterate    14  f =      -31.412  |proj g|=       0.15339
# At iterate    15  f =      -31.429  |proj g|=      0.015675
# At iterate    16  f =      -31.429  |proj g|=     0.0010671
# At iterate    17  f =      -31.429  |proj g|=    8.2123e-06
# At iterate    18  f =      -31.429  |proj g|=    4.3499e-09
#
# iterations 18
# function evaluations 21
# segments explored during Cauchy searches 19
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 4.34993e-09
# final function value -31.4291
#
# F = -31.4291
# final  value -31.429059
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3702416 180 90
#   - best initial criterion value(s) :  29.6059
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -29.606  |proj g|=      0.42501
# At iterate     1  f =      -32.083  |proj g|=       0.50464
# At iterate     2  f =       -32.52  |proj g|=       0.43744
# At iterate     3  f =      -33.324  |proj g|=      0.043798
# At iterate     4  f =       -33.33  |proj g|=       0.04507
# At iterate     5  f =      -33.333  |proj g|=        0.0443
# At iterate     6  f =      -33.336  |proj g|=      0.043619
# At iterate     7  f =      -33.351  |proj g|=      0.042836
# At iterate     8  f =      -33.381  |proj g|=      0.089099
# At iterate     9  f =      -33.451  |proj g|=       0.14626
# At iterate    10  f =      -33.575  |proj g|=       0.18359
# At iterate    11  f =       -33.74  |proj g|=       0.17556
# At iterate    12  f =      -33.917  |proj g|=      0.084332
# At iterate    13  f =      -33.986  |proj g|=      0.086892
# At iterate    14  f =      -34.009  |proj g|=      0.064239
# At iterate    15  f =      -34.319  |proj g|=       0.44334
# At iterate    16  f =       -34.43  |proj g|=      0.093972
# At iterate    17  f =      -34.436  |proj g|=      0.014121
# At iterate    18  f =      -34.436  |proj g|=    0.00057474
# At iterate    19  f =      -34.436  |proj g|=    3.7376e-06
# At iterate    20  f =      -34.436  |proj g|=    9.9878e-10
#
# iterations 20
# function evaluations 25
# segments explored during Cauchy searches 21
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 9.98777e-10
# final function value -34.4361
#
# F = -34.4361
# final  value -34.436124
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3798985 180 90
#   - best initial criterion value(s) :  35.02568
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -35.026  |proj g|=      0.23339
# At iterate     1  f =      -35.893  |proj g|=       0.15291
# At iterate     2  f =      -35.913  |proj g|=       0.11402
# At iterate     3  f =       -35.94  |proj g|=      0.010186
# At iterate     4  f =      -35.941  |proj g|=     0.0076385
# At iterate     5  f =      -35.941  |proj g|=     0.0075097
# At iterate     6  f =      -35.941  |proj g|=     0.0095853
# At iterate     7  f =      -35.942  |proj g|=      0.019231
# At iterate     8  f =      -35.945  |proj g|=      0.034283
# At iterate     9  f =      -35.952  |proj g|=      0.051017
# At iterate    10  f =      -35.962  |proj g|=        0.0599
# At iterate    11  f =      -35.976  |proj g|=      0.047982
# At iterate    12  f =      -35.985  |proj g|=      0.013672
# At iterate    13  f =      -35.987  |proj g|=     0.0046445
# At iterate    14  f =      -35.987  |proj g|=     0.0065032
# At iterate    15  f =      -35.988  |proj g|=     0.0058925
# At iterate    16  f =      -36.078  |proj g|=       0.30265
# ys=-2.364e-03  -gs= 9.356e-03, BFGS update SKIPPED
# At iterate    17  f =      -36.111  |proj g|=       0.11891
# At iterate    18  f =       -36.39  |proj g|=      0.053798
# ys=-5.673e-02  -gs= 2.233e-01, BFGS update SKIPPED
# At iterate    19  f =      -36.392  |proj g|=      0.015995
# At iterate    20  f =      -36.392  |proj g|=    0.00038419
# At iterate    21  f =      -36.392  |proj g|=    2.8442e-06
# At iterate    22  f =      -36.392  |proj g|=    5.0032e-10
#
# iterations 22
# function evaluations 29
# segments explored during Cauchy searches 23
# BFGS updates skipped 2
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 5.00316e-10
# final function value -36.3917
#
# F = -36.3917
# final  value -36.391697
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3798985 180 90
#   - best initial criterion value(s) :  36.85312
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -36.853  |proj g|=      0.30907
# At iterate     1  f =      -38.853  |proj g|=        0.2456
# At iterate     2  f =      -38.882  |proj g|=       0.21872
# At iterate     3  f =      -38.968  |proj g|=      0.075118
# At iterate     4  f =      -38.976  |proj g|=      0.015802
# At iterate     5  f =      -38.976  |proj g|=     0.0025172
# At iterate     6  f =      -38.976  |proj g|=     0.0025799
# At iterate     7  f =      -38.976  |proj g|=      0.005394
# At iterate     8  f =      -38.976  |proj g|=      0.012171
# At iterate     9  f =      -38.977  |proj g|=      0.025642
# At iterate    10  f =       -38.98  |proj g|=      0.053832
# At iterate    11  f =      -38.986  |proj g|=        0.1408
# At iterate    12  f =      -38.997  |proj g|=       0.20735
# At iterate    13  f =      -39.021  |proj g|=       0.33621
# At iterate    14  f =      -39.064  |proj g|=       0.50227
# At iterate    15  f =      -39.229  |proj g|=       0.58834
# At iterate    16  f =       -39.39  |proj g|=       0.12881
# At iterate    17  f =        -39.4  |proj g|=      0.022569
# At iterate    18  f =        -39.4  |proj g|=     0.0011869
# At iterate    19  f =        -39.4  |proj g|=    1.1929e-05
# At iterate    20  f =        -39.4  |proj g|=    6.4077e-09
#
# iterations 20
# function evaluations 24
# segments explored during Cauchy searches 21
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 6.40774e-09
# final function value -39.3999
#
# F = -39.3999
# final  value -39.399859
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3798985 180 90
#   - best initial criterion value(s) :  40.82067
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -40.821  |proj g|=      0.11272
# At iterate     1  f =      -41.036  |proj g|=      0.074967
# At iterate     2  f =      -41.041  |proj g|=      0.055012
# At iterate     3  f =      -41.048  |proj g|=     0.0043963
# At iterate     4  f =      -41.048  |proj g|=     0.0042411
# At iterate     5  f =      -41.048  |proj g|=     0.0041568
# At iterate     6  f =      -41.048  |proj g|=     0.0053122
# At iterate     7  f =      -41.048  |proj g|=      0.010397
# At iterate     8  f =      -41.049  |proj g|=      0.018849
# At iterate     9  f =      -41.051  |proj g|=      0.030802
# At iterate    10  f =      -41.054  |proj g|=      0.044368
# At iterate    11  f =      -41.062  |proj g|=       0.05324
# At iterate    12  f =       -41.18  |proj g|=       0.23462
# At iterate    13  f =      -41.185  |proj g|=       0.30847
# At iterate    14  f =      -41.312  |proj g|=       0.43165
# At iterate    15  f =      -41.608  |proj g|=       0.44557
# At iterate    16  f =      -41.707  |proj g|=      0.019279
# At iterate    17  f =      -41.707  |proj g|=     0.0026668
# At iterate    18  f =      -41.707  |proj g|=    2.0095e-05
# At iterate    19  f =      -41.707  |proj g|=    2.0708e-08
#
# iterations 19
# function evaluations 25
# segments explored during Cauchy searches 20
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 2.07077e-08
# final function value -41.7068
#
# F = -41.7068
# final  value -41.706813
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3798994 180 90
#   - best initial criterion value(s) :  42.72836
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -42.728  |proj g|=      0.26896
# At iterate     1  f =       -43.31  |proj g|=        0.2362
# At iterate     2  f =      -43.375  |proj g|=        0.1682
# At iterate     3  f =      -43.429  |proj g|=      0.045219
# At iterate     4  f =      -43.432  |proj g|=     0.0062937
# At iterate     5  f =      -43.432  |proj g|=    0.00064821
# At iterate     6  f =      -43.432  |proj g|=    0.00066196
# At iterate     7  f =      -43.432  |proj g|=     0.0010811
# At iterate     8  f =      -43.432  |proj g|=      0.002417
# At iterate     9  f =      -43.433  |proj g|=     0.0049703
# At iterate    10  f =      -43.433  |proj g|=     0.0095652
# At iterate    11  f =      -43.433  |proj g|=      0.020742
# At iterate    12  f =      -43.434  |proj g|=      0.065711
# At iterate    13  f =      -43.436  |proj g|=        0.1156
# At iterate    14  f =       -43.44  |proj g|=       0.18758
# At iterate    15  f =      -43.452  |proj g|=       0.37814
# At iterate    16  f =       -43.82  |proj g|=       0.63681
# At iterate    17  f =      -44.104  |proj g|=      0.042946
# At iterate    18  f =      -44.105  |proj g|=     0.0065606
# At iterate    19  f =      -44.105  |proj g|=    0.00010195
# At iterate    20  f =      -44.105  |proj g|=    2.4779e-07
#
# iterations 20
# function evaluations 23
# segments explored during Cauchy searches 21
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 2.47787e-07
# final function value -44.1054
#
# F = -44.1054
# final  value -44.105380
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3798994 180 90
#   - best initial criterion value(s) :  40.46449
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -40.464  |proj g|=      0.12387
# At iterate     1  f =      -40.615  |proj g|=      0.099398
# At iterate     2  f =      -40.619  |proj g|=      0.038247
# At iterate     3  f =      -40.619  |proj g|=      0.023373
# At iterate     4  f =      -40.619  |proj g|=       0.02342
# At iterate     5  f =      -40.619  |proj g|=       0.07359
# At iterate     6  f =      -40.619  |proj g|=       0.15362
# At iterate     7  f =       -40.62  |proj g|=       0.28528
# At iterate     8  f =       -40.62  |proj g|=       0.28568
# At iterate     9  f =       -40.62  |proj g|=        0.2863
# At iterate    10  f =      -40.621  |proj g|=       0.28707
# At iterate    11  f =      -40.623  |proj g|=        0.2875
# At iterate    12  f =      -40.624  |proj g|=      0.094554
# At iterate    13  f =      -40.625  |proj g|=     0.0057957
# At iterate    14  f =      -40.625  |proj g|=      0.005815
# At iterate    15  f =      -40.625  |proj g|=     0.0058322
# At iterate    16  f =      -40.625  |proj g|=      0.015854
# At iterate    17  f =      -40.625  |proj g|=      0.031576
# At iterate    18  f =      -40.625  |proj g|=       0.13173
# At iterate    19  f =      -40.625  |proj g|=     0.0077887
# At iterate    20  f =      -40.625  |proj g|=       0.28739
# At iterate    21  f =      -41.626  |proj g|=       0.35202
# At iterate    22  f =      -41.642  |proj g|=       0.35349
# At iterate    23  f =      -42.152  |proj g|=       0.10168
# At iterate    24  f =      -42.448  |proj g|=       0.35782
# At iterate    25  f =      -42.704  |proj g|=       0.35534
# At iterate    26  f =      -42.742  |proj g|=       0.35676
# At iterate    27  f =      -42.775  |proj g|=       0.02465
# At iterate    28  f =      -42.775  |proj g|=      0.024485
# At iterate    29  f =      -42.775  |proj g|=     0.0049042
# At iterate    30  f =      -42.775  |proj g|=    0.00022817
#
# iterations 30
# function evaluations 44
# segments explored during Cauchy searches 31
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0.000228174
# final function value -42.775
#
# F = -42.775
# final  value -42.775010
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3798994 180 90
#   - best initial criterion value(s) :  45.76926
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -45.769  |proj g|=      0.65424
# At iterate     1  f =      -46.864  |proj g|=       0.66653
# At iterate     2  f =      -48.843  |proj g|=       0.30843
# At iterate     3  f =      -49.065  |proj g|=      0.028385
# At iterate     4  f =      -49.067  |proj g|=     0.0078241
# At iterate     5  f =      -49.067  |proj g|=     0.0007779
# At iterate     6  f =      -49.067  |proj g|=     0.0016736
# At iterate     7  f =      -49.067  |proj g|=     0.0056468
# At iterate     8  f =      -49.067  |proj g|=       0.01365
# At iterate     9  f =      -49.068  |proj g|=      0.022751
# At iterate    10  f =      -49.069  |proj g|=      0.022096
# At iterate    11  f =       -49.07  |proj g|=     0.0099853
# At iterate    12  f =       -49.07  |proj g|=     0.0003881
# At iterate    13  f =       -49.07  |proj g|=    3.1717e-05
# At iterate    14  f =       -49.07  |proj g|=    1.1689e-06
#
# iterations 14
# function evaluations 18
# segments explored during Cauchy searches 15
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 1.16887e-06
# final function value -49.0698
#
# F = -49.0698
# final  value -49.069780
# converged
# Loading required package: pROC
#
# Type 'citation("pROC")' for a citation.
#
#
# Attaching package: ‘pROC’
#
#
# The following objects are masked from ‘package:stats’:
#
#     cov, smooth, var
#
#
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3441321 166 88
#   - best initial criterion value(s) :  13.90651
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -13.907  |proj g|=      0.35349
# At iterate     1  f =      -14.201  |proj g|=       0.38557
# At iterate     2  f =      -15.018  |proj g|=       0.14109
# At iterate     3  f =      -15.043  |proj g|=      0.093375
# At iterate     4  f =      -15.063  |proj g|=     0.0043872
# At iterate     5  f =      -15.063  |proj g|=     0.0043728
# At iterate     6  f =      -15.064  |proj g|=     0.0069968
# At iterate     7  f =      -15.065  |proj g|=      0.016004
# At iterate     8  f =      -15.067  |proj g|=       0.03172
# At iterate     9  f =      -15.073  |proj g|=       0.05535
# At iterate    10  f =      -15.087  |proj g|=      0.089756
# At iterate    11  f =      -15.123  |proj g|=       0.13003
# At iterate    12  f =      -15.163  |proj g|=       0.11286
# At iterate    13  f =       -15.19  |proj g|=       0.01402
# At iterate    14  f =      -15.191  |proj g|=    0.00012373
# At iterate    15  f =      -15.191  |proj g|=     1.589e-07
#
# iterations 15
# function evaluations 17
# segments explored during Cauchy searches 16
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 1.58901e-07
# final function value -15.1909
#
# F = -15.1909
# final  value -15.190901
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3441321 174 88
#   - best initial criterion value(s) :  15.01099
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -15.011  |proj g|=      0.23976
# At iterate     1  f =      -15.936  |proj g|=        0.1013
# At iterate     2  f =      -16.016  |proj g|=      0.075489
# At iterate     3  f =      -16.066  |proj g|=      0.021865
# At iterate     4  f =      -16.068  |proj g|=      0.022197
# At iterate     5  f =       -16.07  |proj g|=       0.02211
# At iterate     6  f =      -16.093  |proj g|=      0.028016
# At iterate     7  f =      -16.141  |proj g|=      0.073671
# At iterate     8  f =      -16.233  |proj g|=       0.13251
# At iterate     9  f =      -16.476  |proj g|=        0.2021
# At iterate    10  f =      -17.095  |proj g|=       0.15278
# At iterate    11  f =      -17.173  |proj g|=      0.067067
# At iterate    12  f =      -17.178  |proj g|=     0.0084212
# At iterate    13  f =      -17.179  |proj g|=    0.00019703
# At iterate    14  f =      -17.179  |proj g|=    6.6104e-07
# At iterate    15  f =      -17.179  |proj g|=    5.2749e-11
#
# iterations 15
# function evaluations 21
# segments explored during Cauchy searches 16
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 5.27487e-11
# final function value -17.1785
#
# F = -17.1785
# final  value -17.178542
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3441321 174 88
#   - best initial criterion value(s) :  16.64558
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -16.646  |proj g|=      0.18591
# At iterate     1  f =      -16.655  |proj g|=       0.17667
# At iterate     2  f =      -16.655  |proj g|=      0.034446
# At iterate     3  f =      -16.655  |proj g|=      0.034425
# At iterate     4  f =      -16.655  |proj g|=       0.10975
# At iterate     5  f =      -16.656  |proj g|=        0.1763
# At iterate     6  f =      -16.657  |proj g|=         0.178
# At iterate     7  f =      -16.659  |proj g|=       0.18055
# At iterate     8  f =      -16.665  |proj g|=       0.18457
# At iterate     9  f =       -16.68  |proj g|=       0.19027
# At iterate    10  f =      -16.715  |proj g|=       0.19718
# At iterate    11  f =      -16.797  |proj g|=       0.20156
# At iterate    12  f =      -17.085  |proj g|=       0.16969
# At iterate    13  f =      -17.175  |proj g|=       0.17182
# At iterate    14  f =       -17.19  |proj g|=       0.17082
# At iterate    15  f =       -17.25  |proj g|=       0.16021
# At iterate    16  f =      -17.344  |proj g|=       0.13441
# At iterate    17  f =      -17.642  |proj g|=      0.064781
# At iterate    18  f =      -17.667  |proj g|=      0.035312
# At iterate    19  f =      -17.759  |proj g|=      0.064737
# At iterate    20  f =      -17.985  |proj g|=       0.17133
# At iterate    21  f =      -18.658  |proj g|=       0.15314
# At iterate    22  f =      -18.842  |proj g|=      0.051365
# At iterate    23  f =      -18.964  |proj g|=      0.018055
# At iterate    24  f =       -18.98  |proj g|=     0.0095622
# At iterate    25  f =       -18.98  |proj g|=    0.00036486
# At iterate    26  f =       -18.98  |proj g|=    1.5652e-06
# At iterate    27  f =       -18.98  |proj g|=    2.5248e-10
#
# iterations 27
# function evaluations 35
# segments explored during Cauchy searches 29
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 2.52483e-10
# final function value -18.9804
#
# F = -18.9804
# final  value -18.980355
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3441321 180 88
#   - best initial criterion value(s) :  19.08802
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -19.088  |proj g|=      0.15588
# At iterate     1  f =       -19.59  |proj g|=      0.056882
# At iterate     2  f =      -19.595  |proj g|=      0.034538
# At iterate     3  f =      -19.604  |proj g|=      0.033266
# At iterate     4  f =      -19.612  |proj g|=      0.048686
# At iterate     5  f =      -19.653  |proj g|=       0.13651
# At iterate     6  f =      -19.736  |proj g|=       0.24248
# At iterate     7  f =       -19.97  |proj g|=       0.39516
# At iterate     8  f =      -20.564  |proj g|=       0.44333
# At iterate     9  f =      -21.317  |proj g|=      0.083603
# At iterate    10  f =      -21.337  |proj g|=      0.063091
# At iterate    11  f =      -21.341  |proj g|=     0.0042236
# At iterate    12  f =      -21.341  |proj g|=    0.00012553
# At iterate    13  f =      -21.341  |proj g|=    2.3045e-07
#
# iterations 13
# function evaluations 16
# segments explored during Cauchy searches 14
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 2.30449e-07
# final function value -21.3407
#
# F = -21.3407
# final  value -21.340709
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3509444 180 88
#   - best initial criterion value(s) :  21.3366
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -21.337  |proj g|=      0.02208
# At iterate     1  f =      -21.384  |proj g|=      0.011919
# At iterate     2  f =      -21.385  |proj g|=      0.011887
# At iterate     3  f =      -21.388  |proj g|=      0.019912
# At iterate     4  f =      -21.392  |proj g|=      0.032292
# At iterate     5  f =      -21.413  |proj g|=       0.07452
# ...
# At iterate    12  f =      -43.807  |proj g|=       0.21692
# At iterate    13  f =      -43.818  |proj g|=       0.21974
# At iterate    14  f =      -43.845  |proj g|=       0.22372
# At iterate    15  f =      -43.915  |proj g|=       0.22982
# At iterate    16  f =       -44.08  |proj g|=       0.39267
# At iterate    17  f =      -44.439  |proj g|=       0.66064
# At iterate    18  f =      -45.085  |proj g|=       0.43557
# At iterate    19  f =      -45.779  |proj g|=       0.46848
# At iterate    20  f =      -45.864  |proj g|=       0.26702
# At iterate    21  f =      -45.893  |proj g|=       0.16146
# At iterate    22  f =      -45.894  |proj g|=      0.090848
# At iterate    23  f =      -45.894  |proj g|=     0.0030636
# At iterate    24  f =      -45.894  |proj g|=    0.00034633
#
# iterations 24
# function evaluations 28
# segments explored during Cauchy searches 25
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0.000346329
# final function value -45.8936
#
# F = -45.8936
# final  value -45.893609
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3799971 180 90
#   - best initial criterion value(s) :  40.84142
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -40.841  |proj g|=      0.34448
# At iterate     1  f =      -42.397  |proj g|=       0.48537
# At iterate     2  f =      -43.974  |proj g|=        1.2645
# At iterate     3  f =      -44.106  |proj g|=        1.3281
# At iterate     4  f =      -44.127  |proj g|=        1.3277
# At iterate     5  f =      -44.147  |proj g|=        1.3195
# At iterate     6  f =      -44.201  |proj g|=        1.2934
# At iterate     7  f =      -44.343  |proj g|=         1.226
# At iterate     8  f =      -44.749  |proj g|=        1.0584
# At iterate     9  f =      -45.907  |proj g|=       0.44903
# At iterate    10  f =      -46.844  |proj g|=       0.21177
# At iterate    11  f =      -47.645  |proj g|=       0.28004
# At iterate    12  f =      -47.691  |proj g|=       0.21911
# At iterate    13  f =      -47.698  |proj g|=       0.21937
# At iterate    14  f =      -47.698  |proj g|=       0.16157
# At iterate    15  f =      -47.698  |proj g|=       0.12663
# At iterate    16  f =      -47.698  |proj g|=      0.051274
# At iterate    17  f =      -47.699  |proj g|=       0.21924
# At iterate    18  f =      -47.699  |proj g|=       0.21985
# At iterate    19  f =      -47.701  |proj g|=       0.22086
# At iterate    20  f =      -47.705  |proj g|=       0.22243
# At iterate    21  f =      -47.715  |proj g|=       0.22482
# At iterate    22  f =       -47.74  |proj g|=       0.22825
# At iterate    23  f =      -47.799  |proj g|=       0.23219
# At iterate    24  f =      -47.916  |proj g|=       0.44607
# At iterate    25  f =       -48.12  |proj g|=        0.6646
# At iterate    26  f =      -48.128  |proj g|=       0.64706
# At iterate    27  f =      -48.183  |proj g|=       0.51358
# At iterate    28  f =      -48.256  |proj g|=       0.30766
# At iterate    29  f =      -48.341  |proj g|=       0.16905
# At iterate    30  f =      -48.363  |proj g|=       0.16247
# At iterate    31  f =      -48.365  |proj g|=      0.024903
# At iterate    32  f =      -48.365  |proj g|=     0.0010248
# At iterate    33  f =      -48.365  |proj g|=    0.00034778
#
# iterations 33
# function evaluations 38
# segments explored during Cauchy searches 34
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0.000347779
# final function value -48.3648
#
# F = -48.3648
# final  value -48.364774
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3799971 180 90
#   - best initial criterion value(s) :  42.68848
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -42.688  |proj g|=       6.1255
# At iterate     1  f =      -47.373  |proj g|=        2.2552
# At iterate     2  f =      -48.589  |proj g|=        1.4024
# At iterate     3  f =      -49.173  |proj g|=       0.50983
# At iterate     4  f =      -49.269  |proj g|=      0.092031
# At iterate     5  f =      -49.273  |proj g|=       0.10595
# At iterate     6  f =      -49.273  |proj g|=      0.031988
# At iterate     7  f =      -49.273  |proj g|=       0.16179
# At iterate     8  f =      -49.274  |proj g|=       0.21895
# At iterate     9  f =      -49.276  |proj g|=       0.13937
# At iterate    10  f =      -49.284  |proj g|=       0.16375
# At iterate    11  f =      -49.307  |proj g|=       0.16723
# At iterate    12  f =      -49.361  |proj g|=       0.22365
# At iterate    13  f =      -49.489  |proj g|=       0.32177
# At iterate    14  f =      -49.754  |proj g|=       0.48545
# At iterate    15  f =      -50.127  |proj g|=       0.60945
# At iterate    16  f =       -50.31  |proj g|=        0.5911
# At iterate    17  f =      -50.409  |proj g|=       0.42626
# At iterate    18  f =      -50.463  |proj g|=       0.23402
# At iterate    19  f =      -50.496  |proj g|=       0.16383
# At iterate    20  f =      -50.501  |proj g|=      0.049385
# At iterate    21  f =      -50.501  |proj g|=     0.0011942
# At iterate    22  f =      -50.501  |proj g|=    8.4801e-05
#
# iterations 22
# function evaluations 25
# segments explored during Cauchy searches 23
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 8.48011e-05
# final function value -50.5009
#
# F = -50.5009
# final  value -50.500888
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3799971 180 90
#   - best initial criterion value(s) :  41.00024
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=          -41  |proj g|=      0.31994
# At iterate     1  f =      -41.706  |proj g|=       0.28693
# At iterate     2  f =       -42.96  |proj g|=       0.24767
# At iterate     3  f =      -42.977  |proj g|=       0.21332
# At iterate     4  f =      -42.987  |proj g|=       0.21451
# At iterate     5  f =      -42.987  |proj g|=       0.21268
# At iterate     6  f =      -42.988  |proj g|=       0.20817
# At iterate     7  f =       -42.99  |proj g|=       0.20746
# At iterate     8  f =      -42.994  |proj g|=       0.20968
# At iterate     9  f =      -43.005  |proj g|=       0.21215
# At iterate    10  f =      -43.029  |proj g|=       0.21325
# At iterate    11  f =      -43.062  |proj g|=        0.2088
# At iterate    12  f =      -43.078  |proj g|=       0.18408
# At iterate    13  f =      -43.079  |proj g|=      0.039653
# At iterate    14  f =      -43.079  |proj g|=      0.018244
# At iterate    15  f =      -43.079  |proj g|=      0.022166
# At iterate    16  f =      -43.079  |proj g|=      0.087087
# At iterate    17  f =      -43.079  |proj g|=       0.19893
# At iterate    18  f =      -43.079  |proj g|=        0.1994
# At iterate    19  f =       -43.08  |proj g|=       0.20011
# At iterate    20  f =      -43.083  |proj g|=       0.20088
# At iterate    21  f =       -43.09  |proj g|=       0.20106
# At iterate    22  f =      -43.106  |proj g|=       0.19937
# At iterate    23  f =      -43.142  |proj g|=       0.21537
# At iterate    24  f =      -43.219  |proj g|=       0.37546
# At iterate    25  f =      -43.224  |proj g|=       0.37346
# At iterate    26  f =      -43.332  |proj g|=       0.43017
# At iterate    27  f =      -43.688  |proj g|=       0.14497
# At iterate    28  f =      -43.728  |proj g|=       0.15944
# At iterate    29  f =      -43.857  |proj g|=      0.082582
# At iterate    30  f =      -43.881  |proj g|=      0.062849
# At iterate    31  f =      -43.897  |proj g|=      0.052356
# At iterate    32  f =        -43.9  |proj g|=      0.043803
# At iterate    33  f =      -43.901  |proj g|=     0.0065179
# At iterate    34  f =      -43.901  |proj g|=    0.00080174
# At iterate    35  f =      -43.901  |proj g|=    0.00035425
#
# iterations 35
# function evaluations 42
# segments explored during Cauchy searches 36
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 0.000354246
# final function value -43.9006
#
# F = -43.9006
# final  value -43.900650
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3799971 180 90
#   - best initial criterion value(s) :  46.06753
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -46.068  |proj g|=       4.1171
# At iterate     1  f =      -46.494  |proj g|=       0.71068
# At iterate     2  f =      -47.623  |proj g|=       0.82158
# At iterate     3  f =      -47.963  |proj g|=        1.0318
# At iterate     4  f =      -48.806  |proj g|=       0.22664
# At iterate     5  f =      -48.924  |proj g|=       0.20382
# At iterate     6  f =      -48.994  |proj g|=       0.18691
# At iterate     7  f =      -48.998  |proj g|=       0.19881
# At iterate     8  f =      -48.998  |proj g|=      0.071061
# At iterate     9  f =      -48.998  |proj g|=      0.070915
# At iterate    10  f =       -49.01  |proj g|=       0.07002
# At iterate    11  f =      -49.079  |proj g|=       0.20302
# At iterate    12  f =       -49.27  |proj g|=       0.45107
# At iterate    13  f =      -49.302  |proj g|=       0.39616
# At iterate    14  f =       -49.72  |proj g|=       0.70479
# At iterate    15  f =      -50.515  |proj g|=        1.1205
# At iterate    16  f =      -51.506  |proj g|=        1.0376
# At iterate    17  f =      -52.381  |proj g|=       0.65662
# At iterate    18  f =      -52.524  |proj g|=       0.27721
# At iterate    19  f =       -52.53  |proj g|=       0.28868
# At iterate    20  f =       -52.55  |proj g|=       0.16298
# At iterate    21  f =      -52.552  |proj g|=     0.0093084
# At iterate    22  f =      -52.552  |proj g|=    0.00057097
# At iterate    23  f =      -52.552  |proj g|=    2.5203e-05
#
# iterations 23
# function evaluations 34
# segments explored during Cauchy searches 24
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 2.52034e-05
# final function value -52.552
#
# F = -52.552
# final  value -52.551993
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3799971 180 90
#   - best initial criterion value(s) :  51.55733
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -51.557  |proj g|=        2.762
# At iterate     1  f =      -53.583  |proj g|=        1.5546
# At iterate     2  f =      -54.442  |proj g|=       0.22659
# At iterate     3  f =      -54.482  |proj g|=       0.21844
# At iterate     4  f =      -54.484  |proj g|=       0.21759
# At iterate     5  f =      -54.486  |proj g|=       0.14334
# At iterate     6  f =      -54.486  |proj g|=      0.024143
# At iterate     7  f =      -54.486  |proj g|=      0.024142
# At iterate     8  f =      -54.486  |proj g|=       0.11411
# At iterate     9  f =      -54.487  |proj g|=       0.16388
# At iterate    10  f =      -54.487  |proj g|=       0.16417
# At iterate    11  f =      -54.487  |proj g|=       0.16462
# At iterate    12  f =      -54.488  |proj g|=       0.16534
# At iterate    13  f =       -54.49  |proj g|=       0.16644
# At iterate    14  f =      -54.496  |proj g|=       0.16791
# At iterate    15  f =      -54.507  |proj g|=        0.1873
# At iterate    16  f =      -54.521  |proj g|=       0.31137
# At iterate    17  f =      -54.539  |proj g|=       0.44647
# At iterate    18  f =      -54.565  |proj g|=        0.5802
# At iterate    19  f =      -54.614  |proj g|=       0.73115
# At iterate    20  f =       -54.73  |proj g|=       0.94344
# At iterate    21  f =      -54.933  |proj g|=        1.0367
# At iterate    22  f =      -55.094  |proj g|=       0.70208
# At iterate    23  f =      -55.223  |proj g|=       0.28018
# At iterate    24  f =      -55.248  |proj g|=       0.21796
# At iterate    25  f =       -55.25  |proj g|=      0.012482
# At iterate    26  f =       -55.25  |proj g|=     0.0013055
# At iterate    27  f =       -55.25  |proj g|=    7.4268e-05
#
# iterations 27
# function evaluations 30
# segments explored during Cauchy searches 28
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 7.42682e-05
# final function value -55.2501
#
# F = -55.2501
# final  value -55.250138
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3799971 180 90
#   - best initial criterion value(s) :  53.12087
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -53.121  |proj g|=      0.64341
# At iterate     1  f =      -53.853  |proj g|=       0.95676
# At iterate     2  f =      -54.644  |proj g|=        1.7486
# At iterate     3  f =      -54.692  |proj g|=        1.6663
# At iterate     4  f =      -54.766  |proj g|=        1.5895
# At iterate     5  f =      -55.023  |proj g|=         1.407
# At iterate     6  f =      -55.607  |proj g|=        1.0959
# At iterate     7  f =      -56.711  |proj g|=        0.2631
# At iterate     8  f =      -57.593  |proj g|=       0.44027
# At iterate     9  f =      -57.909  |proj g|=       0.71741
# At iterate    10  f =      -58.079  |proj g|=       0.29746
# At iterate    11  f =      -58.093  |proj g|=       0.16884
# At iterate    12  f =      -58.104  |proj g|=       0.16924
# At iterate    13  f =      -58.104  |proj g|=      0.019116
# At iterate    14  f =      -58.104  |proj g|=      0.019116
# At iterate    15  f =      -58.104  |proj g|=      0.023924
# At iterate    16  f =      -58.104  |proj g|=      0.074155
# At iterate    17  f =      -58.104  |proj g|=       0.13929
# At iterate    18  f =      -58.105  |proj g|=       0.21591
# At iterate    19  f =      -58.106  |proj g|=       0.21536
# At iterate    20  f =      -58.108  |proj g|=       0.21696
# At iterate    21  f =      -58.127  |proj g|=       0.28023
# At iterate    22  f =      -58.177  |proj g|=       0.39772
# At iterate    23  f =      -58.193  |proj g|=       0.42293
# At iterate    24  f =      -58.221  |proj g|=       0.28397
# At iterate    25  f =      -58.239  |proj g|=       0.21637
# At iterate    26  f =      -58.239  |proj g|=       0.16477
# At iterate    27  f =      -58.239  |proj g|=    0.00044058
# At iterate    28  f =      -58.239  |proj g|=    3.3708e-06
#
# iterations 28
# function evaluations 32
# segments explored during Cauchy searches 29
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 3.37078e-06
# final function value -58.2391
#
# F = -58.2391
# final  value -58.239134
# converged
# Setting levels: control = 0, case = 1
#
# Setting direction: controls < cases

# %%
# Paso 7: Comparación visual y resumen
# Guardar resultados como tabla CSV
results_summary <- data.table(
  experimento = c("original", "duplicado"),
  auc = c(as.numeric(res_base$auc), as.numeric(res_augm$auc))
)
fwrite(results_summary, "auc_resultados.csv")
cat("AUC dataset original:", res_base$auc, "\n")
cat("AUC dataset duplicado:", res_augm$auc, "\n")
# Out:
# AUC dataset original: 0.9855769
# AUC dataset duplicado: 0.7739234

# %%
# Gráfica ROC del duplicado
ggroc <- ggroc(list(Original = roc_base, Duplicado = roc_dup))
ggplot(ggroc) +
  geom_line(aes(color = name), size = 1.2) +
  scale_color_manual(values = c("Original" = "red", "Duplicado" = "blue")) +
  labs(title = "Curvas ROC - Comparación", x = "1 - Especificidad", y = "Sensibilidad") +
  theme_minimal() +
  theme(legend.title = element_blank())

ggsave("curvas_roc_comparacion.png", width = 7, height = 5)
# Out:
# Error: object 'roc_base' not found
# Traceback:
#
# 1. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'roc_base' not found", base::quote(eval(expr, envir)))
