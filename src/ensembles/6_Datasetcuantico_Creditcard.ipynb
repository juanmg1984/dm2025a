# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Aug 03 08:55:46 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  656842 35.1 1439214    76.9 1439214  76.9
# Vcells 1224853  9.4 8388608    64.0 1924961  14.7

# %%
PARAM <- list()
PARAM$experimento <- 50002

# %%
# Paso 1: Instalación de paquetes necesarios
if (!require("lightgbm")) install.packages("lightgbm")
if (!require("mlrMBO")) install.packages("mlrMBO")
if (!require("data.table")) install.packages("data.table")
if (!require("DiceKriging")) install.packages("DiceKriging")

library(DiceKriging)
library(lightgbm)
library(mlrMBO)
library(data.table)
library(parallel)
library(smoof)
library(mlr)

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("Cuantico", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
df <- fread("/content/datasets/creditcard.csv")

df[, Class := as.integer(Class)]
cat("Distribución original (positivo = fraude = 1):\n")
print(df[, .N, by = Class])
# Out:
# Distribución original (positivo = fraude = 1):
#    Class      N
#    <int>  <int>
# 1:     0 284315
# 2:     1    492

# %%
# Separar train/test estratificado (1 sola vez)
set.seed(123)
df[, idx := .I]
train_idx <- df[, .SD[sample(.N * 0.7)], by = Class]$idx
train <- df[J(train_idx), on = "idx"]
test  <- df[!J(train_idx), on = "idx"]

# %%
# Columnas predictoras
features <- setdiff(names(train), c("Class", "idx"))

# %%
optimizar_y_entrenar <- function(dataset, nombre_escenario) {
  dataset <- copy(dataset)
  dataset[, idx := NULL]
  
  dtrain <- lgb.Dataset(data = data.matrix(dataset[, ..features]), label = dataset$Class)
  
  param_base <- list(objective="binary", metric="auc", verbosity=-1, feature_pre_filter=FALSE)
  ps <- makeParamSet(
    makeNumericParam("learning_rate", lower=0.01, upper=0.2),
    makeIntegerParam("num_leaves", lower=10L, upper=100L),
    makeIntegerParam("min_data_in_leaf", lower=5L, upper=50L)
  )
  
  obj_fun <- makeSingleObjectiveFunction(
    fn = function(x) {
      x <- as.list(x)
      param <- modifyList(param_base, x)
      cv <- lgb.cv(params=param, data=dtrain, nfold=3, nrounds=100, early_stopping_rounds=10, verbose=-1)
      return(max(unlist(cv$record_evals$valid$auc$eval)))
    },
    par.set = ps, minimize = FALSE
  )
  
  ctrl <- makeMBOControl()
  ctrl <- setMBOControlTermination(ctrl, iters=30)
  ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())
  surrogate <- makeLearner("regr.km", predict.type="se")
  
  run <- suppressMessages(suppressWarnings(mbo(obj_fun, learner=surrogate, control=ctrl)))
  
  # Entrenar modelo final con mejores hiperparámetros
  best_param <- modifyList(param_base, as.list(run$x))
  modelo <- lgb.train(params = best_param, data = dtrain, nrounds = 100, verbose = -1)
  
  # Predecir en test
  yhat <- predict(modelo, data.matrix(test[, ..features]))
  auc_test <- auc(test$Class, yhat)
  
  return(data.table(
    escenario = nombre_escenario,
    learning_rate = run$x$learning_rate,
    num_leaves = run$x$num_leaves,
    min_data_in_leaf = run$x$min_data_in_leaf,
    auc_test = as.numeric(auc_test)
  ))
}

# %%
# Escenario original
res_original <- optimizar_y_entrenar(train, "original")

# Escenario con duplicación de positivos como negativos
duplicados <- copy(train[Class == 1])
duplicados[, Class := 0]
train_duplicado <- rbind(train, duplicados)

res_duplicado <- optimizar_y_entrenar(train_duplicado, "duplicado")

# Combinar resultados
resumen <- rbind(res_original, res_duplicado)
print(resumen)
# Out:
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3419455 160 82
#   - best initial criterion value(s) :  37.85172
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -37.852  |proj g|=      0.13559
# At iterate     1  f =      -38.073  |proj g|=       0.11303
# At iterate     2  f =      -38.181  |proj g|=      0.099643
# At iterate     3  f =      -38.288  |proj g|=       0.29402
# At iterate     4  f =      -38.307  |proj g|=       0.15182
# At iterate     5  f =      -38.307  |proj g|=      0.035843
# At iterate     6  f =      -38.307  |proj g|=      0.018412
# At iterate     7  f =      -38.307  |proj g|=      0.018504
# At iterate     8  f =      -38.307  |proj g|=      0.060052
# At iterate     9  f =      -38.307  |proj g|=      0.064683
# At iterate    10  f =      -38.307  |proj g|=      0.065503
# At iterate    11  f =      -38.308  |proj g|=      0.066844
# At iterate    12  f =      -38.309  |proj g|=      0.069147
# At iterate    13  f =      -38.312  |proj g|=      0.072868
# At iterate    14  f =      -38.319  |proj g|=      0.078036
# At iterate    15  f =      -38.333  |proj g|=      0.082957
# At iterate    16  f =      -38.355  |proj g|=       0.08244
# At iterate    17  f =      -38.363  |proj g|=      0.060954
# At iterate    18  f =      -38.363  |proj g|=     0.0034988
# At iterate    19  f =      -38.363  |proj g|=     0.0035004
# At iterate    20  f =      -38.363  |proj g|=      0.016437
# At iterate    21  f =      -38.363  |proj g|=      0.037777
# At iterate    22  f =      -38.363  |proj g|=      0.070809
# At iterate    23  f =      -38.363  |proj g|=       0.11706
# At iterate    24  f =      -38.363  |proj g|=       0.17276
# At iterate    25  f =      -38.363  |proj g|=        0.2094
# At iterate    26  f =      -38.363  |proj g|=       0.21243
# At iterate    27  f =      -38.363  |proj g|=       0.22148
# At iterate    28  f =      -38.364  |proj g|=       0.24969
# At iterate    29  f =      -38.367  |proj g|=       0.21452
# At iterate    30  f =      -38.373  |proj g|=      0.051863
# At iterate    31  f =      -38.373  |proj g|=     0.0031767
# At iterate    32  f =      -38.373  |proj g|=    0.00016184
# At iterate    33  f =      -38.373  |proj g|=    0.00048271
#
# iterations 33
# function evaluations 39
# segments explored during Cauchy searches 35
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 0.000482705
# final function value -38.3728
#
# F = -38.3728
# final  value -38.372788
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.368028 166 82
#   - best initial criterion value(s) :  42.0598
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       -42.06  |proj g|=      0.32604
# At iterate     1  f =      -42.291  |proj g|=      0.059615
# At iterate     2  f =      -42.295  |proj g|=      0.057973
# At iterate     3  f =      -42.295  |proj g|=       0.07486
# At iterate     4  f =      -42.295  |proj g|=      0.044431
# At iterate     5  f =      -42.295  |proj g|=      0.044431
# At iterate     6  f =      -42.295  |proj g|=      0.057296
# At iterate     7  f =      -42.295  |proj g|=      0.057384
# At iterate     8  f =      -42.295  |proj g|=      0.057543
# At iterate     9  f =      -42.295  |proj g|=      0.057791
# At iterate    10  f =      -42.296  |proj g|=      0.058203
# At iterate    11  f =      -42.297  |proj g|=      0.058879
# At iterate    12  f =      -42.301  |proj g|=       0.06002
# At iterate    13  f =      -42.312  |proj g|=      0.061994
# At iterate    14  f =      -42.342  |proj g|=      0.065652
# At iterate    15  f =      -42.867  |proj g|=       0.10383
# At iterate    16  f =      -42.894  |proj g|=      0.094614
# At iterate    17  f =      -42.903  |proj g|=      0.094124
# At iterate    18  f =      -42.904  |proj g|=      0.096544
# At iterate    19  f =      -42.904  |proj g|=     0.0047864
# At iterate    20  f =      -42.904  |proj g|=     0.0047868
# At iterate    21  f =      -42.904  |proj g|=     0.0048135
# At iterate    22  f =      -42.904  |proj g|=      0.015248
# At iterate    23  f =      -42.904  |proj g|=      0.027266
# At iterate    24  f =      -42.904  |proj g|=      0.041063
# At iterate    25  f =      -42.904  |proj g|=      0.092082
# At iterate    26  f =      -42.904  |proj g|=      0.091804
# At iterate    27  f =      -42.906  |proj g|=       0.27765
# At iterate    28  f =       -42.91  |proj g|=       0.27917
# At iterate    29  f =      -42.917  |proj g|=       0.28092
# At iterate    30  f =      -42.925  |proj g|=       0.28118
# At iterate    31  f =      -42.925  |proj g|=       0.28046
# At iterate    32  f =      -42.932  |proj g|=       0.27891
# At iterate    33  f =      -42.933  |proj g|=       0.09152
# At iterate    34  f =      -42.933  |proj g|=     0.0042431
# At iterate    35  f =      -42.933  |proj g|=     0.0002417
# At iterate    36  f =      -42.933  |proj g|=    1.0783e-05
#
# iterations 36
# function evaluations 46
# segments explored during Cauchy searches 37
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 1.07825e-05
# final function value -42.9334
#
# F = -42.9334
# final  value -42.933434
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.368036 166 82
#   - best initial criterion value(s) :  46.02005
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       -46.02  |proj g|=      0.32097
# At iterate     1  f =       -46.05  |proj g|=      0.055489
# At iterate     2  f =      -46.052  |proj g|=      0.054232
# At iterate     3  f =      -46.052  |proj g|=      0.049398
# At iterate     4  f =      -46.052  |proj g|=      0.049421
# At iterate     5  f =      -46.052  |proj g|=      0.053955
# At iterate     6  f =      -46.052  |proj g|=      0.054082
# At iterate     7  f =      -46.052  |proj g|=      0.054316
# At iterate     8  f =      -46.052  |proj g|=      0.054687
# At iterate     9  f =      -46.053  |proj g|=      0.055318
# At iterate    10  f =      -46.055  |proj g|=      0.056399
# At iterate    11  f =      -46.061  |proj g|=      0.058406
# At iterate    12  f =      -46.079  |proj g|=      0.062683
# At iterate    13  f =      -46.432  |proj g|=       0.11268
# At iterate    14  f =      -46.444  |proj g|=       0.11506
# At iterate    15  f =      -46.505  |proj g|=       0.11038
# At iterate    16  f =      -46.659  |proj g|=       0.28695
# At iterate    17  f =       -46.67  |proj g|=       0.10141
# At iterate    18  f =      -46.682  |proj g|=      0.093565
# At iterate    19  f =      -46.687  |proj g|=       0.27771
# At iterate    20  f =      -46.688  |proj g|=      0.010705
# At iterate    21  f =      -46.688  |proj g|=     0.0095042
# At iterate    22  f =      -46.688  |proj g|=      0.019543
# At iterate    23  f =      -46.688  |proj g|=      0.043898
# At iterate    24  f =      -46.688  |proj g|=       0.11306
# At iterate    25  f =      -46.688  |proj g|=       0.20739
# At iterate    26  f =      -46.688  |proj g|=       0.27703
# At iterate    27  f =      -46.689  |proj g|=       0.27772
# At iterate    28  f =      -46.691  |proj g|=       0.27842
# At iterate    29  f =      -46.693  |proj g|=       0.27935
# At iterate    30  f =      -46.698  |proj g|=       0.27774
# At iterate    31  f =      -46.702  |proj g|=       0.27794
# At iterate    32  f =      -46.707  |proj g|=      0.095198
# At iterate    33  f =      -46.707  |proj g|=       0.01779
# At iterate    34  f =      -46.707  |proj g|=    0.00051075
# At iterate    35  f =      -46.707  |proj g|=    0.00057841
#
# iterations 35
# function evaluations 43
# segments explored during Cauchy searches 37
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 0.000578407
# final function value -46.707
#
# F = -46.707
# final  value -46.707032
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.368036 166 86
#   - best initial criterion value(s) :  46.11284
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -46.113  |proj g|=     0.069439
# At iterate     1  f =        -46.8  |proj g|=      0.024204
# At iterate     2  f =      -46.844  |proj g|=      0.020051
# At iterate     3  f =      -46.844  |proj g|=       0.34915
# At iterate     4  f =      -46.845  |proj g|=      0.019385
# At iterate     5  f =      -46.845  |proj g|=     0.0086276
# At iterate     6  f =      -46.845  |proj g|=     0.0086255
#
# iterations 6
# function evaluations 12
# segments explored during Cauchy searches 8
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 0.00862547
# final function value -46.8449
#
# F = -46.8449
# final  value -46.844890
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.368036 166 86
#   - best initial criterion value(s) :  50.2482
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -50.248  |proj g|=      0.01317
# At iterate     1  f =      -50.278  |proj g|=      0.012622
# At iterate     2  f =      -50.309  |proj g|=       0.35806
# At iterate     3  f =      -50.309  |proj g|=      0.011668
# At iterate     4  f =      -50.309  |proj g|=      0.011656
# At iterate     5  f =      -50.309  |proj g|=      0.013158
#
# iterations 5
# function evaluations 7
# segments explored during Cauchy searches 6
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 0.0131583
# final function value -50.3095
#
# F = -50.3095
# final  value -50.309493
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680381 166 86
#   - best initial criterion value(s) :  55.17018
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       -55.17  |proj g|=      0.03045
# At iterate     1  f =      -55.191  |proj g|=      0.030835
# At iterate     2  f =      -55.235  |proj g|=       0.35824
# At iterate     3  f =      -55.236  |proj g|=      0.032287
# At iterate     4  f =      -55.236  |proj g|=      0.073719
# At iterate     5  f =      -55.236  |proj g|=       0.17554
# At iterate     6  f =      -55.236  |proj g|=       0.35809
# At iterate     7  f =      -55.236  |proj g|=        0.3581
# At iterate     8  f =      -55.236  |proj g|=       0.35811
# At iterate     9  f =      -55.236  |proj g|=       0.35814
# At iterate    10  f =      -55.236  |proj g|=       0.35817
# At iterate    11  f =      -55.237  |proj g|=       0.35822
# At iterate    12  f =      -55.238  |proj g|=       0.35832
# At iterate    13  f =      -55.241  |proj g|=       0.35846
# At iterate    14  f =       -55.25  |proj g|=       0.35866
# At iterate    15  f =       -55.27  |proj g|=        0.3589
# At iterate    16  f =      -55.306  |proj g|=       0.35895
# At iterate    17  f =      -55.334  |proj g|=      0.010003
# At iterate    18  f =      -55.342  |proj g|=     0.0098989
# At iterate    19  f =      -55.342  |proj g|=     0.0098405
# At iterate    20  f =      -55.342  |proj g|=     0.0005722
#
# iterations 20
# function evaluations 24
# segments explored during Cauchy searches 21
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 0.000572202
# final function value -55.3422
#
# F = -55.3422
# final  value -55.342222
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  54.62977
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       -54.63  |proj g|=      0.38898
# At iterate     1  f =       -56.72  |proj g|=       0.42578
# At iterate     2  f =      -57.191  |proj g|=       0.40681
# At iterate     3  f =       -57.57  |proj g|=       0.37708
# At iterate     4  f =      -57.571  |proj g|=       0.37538
# At iterate     5  f =      -57.572  |proj g|=        0.3758
# At iterate     6  f =      -57.572  |proj g|=       0.37555
# At iterate     7  f =      -57.577  |proj g|=       0.37125
# At iterate     8  f =      -57.587  |proj g|=       0.35932
# At iterate     9  f =      -57.613  |proj g|=       0.32499
# At iterate    10  f =      -57.662  |proj g|=       0.25323
# At iterate    11  f =      -57.738  |proj g|=       0.14177
# At iterate    12  f =      -57.822  |proj g|=        0.3482
# At iterate    13  f =      -57.851  |proj g|=      0.026254
# At iterate    14  f =      -57.854  |proj g|=      0.020111
# At iterate    15  f =      -57.854  |proj g|=      0.020003
# At iterate    16  f =      -57.854  |proj g|=     0.0060658
# At iterate    17  f =      -57.854  |proj g|=     0.0060659
#
# iterations 17
# function evaluations 24
# segments explored during Cauchy searches 18
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 0.00606593
# final function value -57.8538
#
# F = -57.8538
# final  value -57.853780
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  52.86243
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -52.862  |proj g|=      0.36171
# At iterate     1  f =      -52.965  |proj g|=       0.44632
# At iterate     2  f =      -52.975  |proj g|=       0.45686
# At iterate     3  f =      -52.984  |proj g|=       0.46597
# At iterate     4  f =      -52.984  |proj g|=       0.46636
# At iterate     5  f =      -52.985  |proj g|=        0.4665
# At iterate     6  f =      -52.988  |proj g|=         0.466
# At iterate     7  f =      -52.998  |proj g|=       0.46213
# At iterate     8  f =      -53.023  |proj g|=       0.45075
# At iterate     9  f =      -53.096  |proj g|=       0.41647
# At iterate    10  f =       -53.28  |proj g|=       0.33464
# At iterate    11  f =      -53.661  |proj g|=       0.16861
# At iterate    12  f =      -54.094  |proj g|=      0.043938
# At iterate    13  f =      -54.174  |proj g|=       0.34645
# At iterate    14  f =      -54.177  |proj g|=      0.047032
# At iterate    15  f =      -54.177  |proj g|=       0.07871
# At iterate    16  f =      -54.177  |proj g|=      0.047028
# At iterate    17  f =      -54.177  |proj g|=      0.047027
# At iterate    18  f =      -54.178  |proj g|=      0.047023
# At iterate    19  f =      -54.178  |proj g|=      0.047018
# At iterate    20  f =      -54.178  |proj g|=      0.047007
# At iterate    21  f =      -54.178  |proj g|=       0.04699
# At iterate    22  f =      -54.178  |proj g|=      0.046966
# At iterate    23  f =      -54.178  |proj g|=      0.046945
# At iterate    24  f =      -54.179  |proj g|=      0.046969
# At iterate    25  f =      -54.181  |proj g|=      0.047143
# At iterate    26  f =      -54.183  |proj g|=      0.047595
# At iterate    27  f =      -54.185  |proj g|=      0.052124
# At iterate    28  f =      -54.189  |proj g|=       0.34643
# At iterate    29  f =      -54.192  |proj g|=       0.34684
# At iterate    30  f =      -54.204  |proj g|=       0.34765
# At iterate    31  f =      -54.232  |proj g|=       0.34889
# At iterate    32  f =      -54.309  |proj g|=       0.35099
# At iterate    33  f =      -54.497  |proj g|=       0.35418
# At iterate    34  f =      -54.911  |proj g|=       0.35808
# At iterate    35  f =      -55.707  |proj g|=       0.47419
# At iterate    36  f =      -56.862  |proj g|=         0.416
# At iterate    37  f =      -57.918  |proj g|=       0.44806
# At iterate    38  f =      -58.004  |proj g|=       0.03968
# At iterate    39  f =      -58.468  |proj g|=      0.020334
# At iterate    40  f =      -58.538  |proj g|=      0.021521
# At iterate    41  f =      -58.561  |proj g|=      0.061708
# At iterate    42  f =      -58.571  |proj g|=      0.025875
# At iterate    43  f =      -58.571  |proj g|=      0.025966
# At iterate    44  f =      -58.576  |proj g|=      0.018043
# At iterate    45  f =      -58.588  |proj g|=       0.02214
# At iterate    46  f =      -58.599  |proj g|=       0.35157
# At iterate    47  f =      -58.607  |proj g|=       0.35249
# At iterate    48  f =      -58.624  |proj g|=       0.35406
# At iterate    49  f =      -58.665  |proj g|=        0.3575
# At iterate    50  f =      -58.754  |proj g|=       0.35872
# At iterate    51  f =      -59.138  |proj g|=      0.051632
# At iterate    52  f =      -59.413  |proj g|=       0.35672
# At iterate    53  f =      -59.699  |proj g|=        0.3562
# At iterate    54  f =      -59.767  |proj g|=       0.17746
# At iterate    55  f =      -59.882  |proj g|=       0.35552
# At iterate    56  f =      -59.906  |proj g|=       0.35504
# At iterate    57  f =      -59.921  |proj g|=       0.35335
# At iterate    58  f =      -59.923  |proj g|=      0.023169
# At iterate    59  f =      -59.925  |proj g|=       0.33322
# At iterate    60  f =      -59.925  |proj g|=       0.35299
# At iterate    61  f =      -59.925  |proj g|=       0.35298
# At iterate    62  f =      -59.925  |proj g|=       0.01512
# At iterate    63  f =      -59.925  |proj g|=      0.070596
# At iterate    64  f =      -59.925  |proj g|=      0.047798
# At iterate    65  f =      -59.925  |proj g|=     0.0073112
# At iterate    66  f =      -59.925  |proj g|=    0.00010255
# At iterate    67  f =      -59.925  |proj g|=    1.3975e-07
#
# iterations 67
# function evaluations 88
# segments explored during Cauchy searches 68
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 1.39746e-07
# final function value -59.9248
#
# F = -59.9248
# final  value -59.924800
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  56.02837
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -56.028  |proj g|=      0.21939
# At iterate     1  f =      -56.156  |proj g|=       0.19602
# At iterate     2  f =      -56.169  |proj g|=       0.35365
# At iterate     3  f =      -56.176  |proj g|=       0.35387
# At iterate     4  f =       -56.22  |proj g|=       0.35458
# At iterate     5  f =      -56.269  |proj g|=       0.35448
# At iterate     6  f =        -56.3  |proj g|=       0.35343
# At iterate     7  f =      -56.303  |proj g|=       0.35295
# At iterate     8  f =      -56.304  |proj g|=      0.046587
# At iterate     9  f =      -56.304  |proj g|=      0.046578
# At iterate    10  f =      -56.304  |proj g|=      0.046565
# At iterate    11  f =      -56.304  |proj g|=      0.046503
# At iterate    12  f =      -56.304  |proj g|=      0.046414
# At iterate    13  f =      -56.304  |proj g|=      0.046282
# At iterate    14  f =      -56.306  |proj g|=      0.046055
# At iterate    15  f =      -56.309  |proj g|=      0.045668
# At iterate    16  f =      -56.317  |proj g|=      0.045009
# At iterate    17  f =      -56.338  |proj g|=      0.049783
# At iterate    18  f =       -56.38  |proj g|=       0.10988
# At iterate    19  f =      -56.438  |proj g|=       0.19265
# At iterate    20  f =       -56.46  |proj g|=       0.20877
# At iterate    21  f =      -56.461  |proj g|=       0.20846
# At iterate    22  f =      -56.466  |proj g|=       0.35416
# At iterate    23  f =      -56.477  |proj g|=       0.35474
# At iterate    24  f =      -56.507  |proj g|=       0.35582
# At iterate    25  f =      -56.575  |proj g|=       0.35737
# At iterate    26  f =      -56.718  |proj g|=       0.35924
# At iterate    27  f =      -57.073  |proj g|=       0.36077
# At iterate    28  f =      -58.313  |proj g|=       0.36103
# At iterate    29  f =      -58.981  |proj g|=       0.57257
# At iterate    30  f =      -59.311  |proj g|=       0.41209
# At iterate    31  f =      -59.485  |proj g|=       0.33314
# At iterate    32  f =      -59.744  |proj g|=       0.17119
# At iterate    33  f =      -59.885  |proj g|=      0.077966
# At iterate    34  f =      -59.919  |proj g|=      0.044636
# At iterate    35  f =      -60.042  |proj g|=       0.35582
# At iterate    36  f =      -60.045  |proj g|=       0.35587
# At iterate    37  f =      -60.046  |proj g|=      0.012202
# At iterate    38  f =      -60.047  |proj g|=      0.012003
# At iterate    39  f =      -60.083  |proj g|=       0.35717
# ys=-2.389e-03  -gs= 5.851e-03, BFGS update SKIPPED
# At iterate    40  f =      -60.174  |proj g|=       0.35734
# At iterate    41  f =      -60.602  |proj g|=       0.35854
# At iterate    42  f =      -60.648  |proj g|=        0.3585
# At iterate    43  f =      -61.462  |proj g|=       0.35728
# At iterate    44  f =       -62.34  |proj g|=       0.35796
# At iterate    45  f =      -62.636  |proj g|=       0.38699
# At iterate    46  f =      -63.037  |proj g|=       0.19581
# At iterate    47  f =      -63.095  |proj g|=       0.32141
# At iterate    48  f =      -63.233  |proj g|=      0.027582
# At iterate    49  f =      -63.239  |proj g|=       0.35244
# At iterate    50  f =      -63.241  |proj g|=       0.35217
# At iterate    51  f =      -63.241  |proj g|=      0.015991
# At iterate    52  f =      -63.241  |proj g|=     0.0058116
# At iterate    53  f =      -63.241  |proj g|=     0.0033827
#
# iterations 53
# function evaluations 75
# segments explored during Cauchy searches 54
# BFGS updates skipped 1
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 0.00338268
# final function value -63.2413
#
# F = -63.2413
# final  value -63.241303
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  57.48506
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -57.485  |proj g|=      0.32099
# At iterate     1  f =      -59.717  |proj g|=       0.39824
# At iterate     2  f =      -60.106  |proj g|=       0.35572
# At iterate     3  f =      -60.115  |proj g|=       0.35506
# At iterate     4  f =      -60.116  |proj g|=       0.35494
# At iterate     5  f =      -60.118  |proj g|=       0.35232
# At iterate     6  f =      -60.125  |proj g|=       0.35719
# At iterate     7  f =      -60.141  |proj g|=        0.3592
# At iterate     8  f =       -60.18  |proj g|=       0.34713
# At iterate     9  f =      -60.263  |proj g|=       0.29834
# At iterate    10  f =      -60.425  |proj g|=       0.18701
# At iterate    11  f =      -60.633  |proj g|=      0.046178
# At iterate    12  f =      -60.663  |proj g|=      0.048452
# At iterate    13  f =      -60.664  |proj g|=      0.048461
# At iterate    14  f =      -60.664  |proj g|=      0.048447
# At iterate    15  f =      -60.664  |proj g|=       0.35384
# At iterate    16  f =      -60.664  |proj g|=       0.35388
# At iterate    17  f =      -60.664  |proj g|=       0.35396
# At iterate    18  f =      -60.666  |proj g|=       0.35409
# At iterate    19  f =      -60.669  |proj g|=       0.35429
# At iterate    20  f =      -60.679  |proj g|=       0.35462
# At iterate    21  f =      -60.704  |proj g|=       0.35516
# At iterate    22  f =       -60.77  |proj g|=       0.35605
# At iterate    23  f =      -60.935  |proj g|=        0.3574
# At iterate    24  f =      -61.296  |proj g|=       0.35905
# At iterate    25  f =      -61.684  |proj g|=       0.46106
# At iterate    26  f =       -61.72  |proj g|=       0.41554
# At iterate    27  f =      -61.752  |proj g|=       0.36041
# At iterate    28  f =      -61.865  |proj g|=       0.42053
# At iterate    29  f =      -62.125  |proj g|=       0.44165
# At iterate    30  f =      -64.991  |proj g|=       0.36097
# ys=-5.586e-01  -gs= 9.238e-01, BFGS update SKIPPED
# At iterate    31  f =      -65.246  |proj g|=       0.36013
# At iterate    32  f =      -65.552  |proj g|=       0.35779
# At iterate    33  f =       -65.83  |proj g|=       0.35615
# At iterate    34  f =      -65.918  |proj g|=       0.35481
# At iterate    35  f =      -65.966  |proj g|=       0.14348
# At iterate    36  f =      -66.024  |proj g|=       0.15157
# At iterate    37  f =      -66.047  |proj g|=       0.14821
# At iterate    38  f =      -66.134  |proj g|=       0.13483
# At iterate    39  f =      -66.344  |proj g|=       0.25359
# At iterate    40  f =      -67.126  |proj g|=       0.35185
# At iterate    41  f =      -67.939  |proj g|=       0.11463
# At iterate    42  f =       -67.97  |proj g|=       0.35316
# At iterate    43  f =      -68.011  |proj g|=        0.3522
# At iterate    44  f =      -68.017  |proj g|=      0.015737
# At iterate    45  f =      -68.018  |proj g|=      0.015641
# At iterate    46  f =      -68.018  |proj g|=      0.012819
# At iterate    47  f =      -68.018  |proj g|=    0.00039388
#
# iterations 47
# function evaluations 73
# segments explored during Cauchy searches 48
# BFGS updates skipped 1
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 0.00039388
# final function value -68.0177
#
# F = -68.0177
# final  value -68.017687
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  62.18361
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -62.184  |proj g|=       1.9945
# At iterate     1  f =      -64.806  |proj g|=       0.74144
# At iterate     2  f =      -65.587  |proj g|=        0.6685
# At iterate     3  f =      -67.193  |proj g|=       0.58703
# At iterate     4  f =      -67.232  |proj g|=       0.58238
# At iterate     5  f =      -68.602  |proj g|=       0.35302
# At iterate     6  f =      -69.295  |proj g|=       0.35628
# At iterate     7  f =      -69.486  |proj g|=       0.12013
# At iterate     8  f =      -69.703  |proj g|=      0.096198
# At iterate     9  f =      -69.798  |proj g|=       0.35797
# At iterate    10  f =      -69.823  |proj g|=        0.3576
# At iterate    11  f =      -69.825  |proj g|=        0.3577
# At iterate    12  f =       -70.24  |proj g|=       0.35688
# At iterate    13  f =      -70.399  |proj g|=       0.35621
# At iterate    14  f =      -70.443  |proj g|=       0.35558
# At iterate    15  f =      -70.448  |proj g|=      0.021017
# At iterate    16  f =      -70.465  |proj g|=      0.070914
# At iterate    17  f =      -70.477  |proj g|=       0.35411
# At iterate    18  f =      -70.478  |proj g|=      0.013888
# At iterate    19  f =      -70.478  |proj g|=      0.045254
# At iterate    20  f =      -70.478  |proj g|=      0.016747
# At iterate    21  f =      -70.478  |proj g|=    0.00071831
#
# iterations 21
# function evaluations 44
# segments explored during Cauchy searches 21
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 0.000718309
# final function value -70.4782
#
# F = -70.4782
# final  value -70.478217
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  65.17141
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -65.171  |proj g|=       0.8045
# At iterate     1  f =      -70.903  |proj g|=       0.75222
# At iterate     2  f =      -70.916  |proj g|=       0.78741
# At iterate     3  f =      -71.143  |proj g|=        0.7064
# At iterate     4  f =      -72.064  |proj g|=       0.35397
# At iterate     5  f =        -72.1  |proj g|=      0.040521
# At iterate     6  f =      -72.102  |proj g|=       0.35394
# At iterate     7  f =      -72.103  |proj g|=      0.041052
# At iterate     8  f =      -72.103  |proj g|=      0.041053
# At iterate     9  f =      -72.103  |proj g|=      0.041053
# At iterate    10  f =      -72.103  |proj g|=       0.28126
# At iterate    11  f =      -72.103  |proj g|=       0.35379
# At iterate    12  f =      -72.103  |proj g|=        0.3538
# At iterate    13  f =      -72.104  |proj g|=       0.35382
# At iterate    14  f =      -72.104  |proj g|=       0.35384
# At iterate    15  f =      -72.104  |proj g|=       0.35388
# At iterate    16  f =      -72.105  |proj g|=       0.35392
# At iterate    17  f =      -72.106  |proj g|=       0.35398
# At iterate    18  f =       -72.11  |proj g|=       0.35399
# At iterate    19  f =      -72.112  |proj g|=       0.35422
# At iterate    20  f =       -72.12  |proj g|=       0.35422
# At iterate    21  f =      -72.172  |proj g|=       0.35423
# At iterate    22  f =      -72.285  |proj g|=       0.26367
# At iterate    23  f =      -72.579  |proj g|=       0.40985
# At iterate    24  f =      -73.023  |proj g|=       0.46508
# At iterate    25  f =      -73.144  |proj g|=       0.26053
# At iterate    26  f =      -73.326  |proj g|=       0.13919
# At iterate    27  f =       -73.41  |proj g|=       0.35597
# At iterate    28  f =      -73.501  |proj g|=      0.037514
# At iterate    29  f =      -73.507  |proj g|=      0.013187
# At iterate    30  f =      -73.507  |proj g|=       0.01318
# At iterate    31  f =      -73.507  |proj g|=      0.013149
# At iterate    32  f =      -73.507  |proj g|=      0.014597
# At iterate    33  f =      -73.507  |proj g|=    9.4192e-06
#
# iterations 33
# function evaluations 42
# segments explored during Cauchy searches 34
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 9.41916e-06
# final function value -73.507
#
# F = -73.507
# final  value -73.506993
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  67.11825
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -67.118  |proj g|=       2.9368
# At iterate     1  f =      -68.563  |proj g|=        1.5635
# At iterate     2  f =      -70.227  |proj g|=       0.53003
# At iterate     3  f =      -72.224  |proj g|=       0.63968
# At iterate     4  f =      -72.887  |proj g|=       0.75741
# At iterate     5  f =      -73.463  |proj g|=       0.47433
# At iterate     6  f =      -74.167  |proj g|=       0.35188
# At iterate     7  f =      -74.171  |proj g|=       0.35193
# At iterate     8  f =      -74.171  |proj g|=       0.04933
# At iterate     9  f =      -74.171  |proj g|=      0.049331
# At iterate    10  f =      -74.171  |proj g|=      0.049331
# At iterate    11  f =      -74.171  |proj g|=      0.049343
# At iterate    12  f =      -74.172  |proj g|=       0.04939
# At iterate    13  f =      -74.173  |proj g|=      0.049096
# At iterate    14  f =      -74.176  |proj g|=      0.049213
# At iterate    15  f =      -74.185  |proj g|=      0.047842
# At iterate    16  f =      -74.221  |proj g|=      0.075856
# At iterate    17  f =      -77.103  |proj g|=       0.35383
# At iterate    18  f =      -77.993  |proj g|=       0.35522
# At iterate    19  f =      -78.088  |proj g|=      0.055341
# At iterate    20  f =      -78.094  |proj g|=       0.35479
# At iterate    21  f =      -78.095  |proj g|=      0.039725
# At iterate    22  f =      -78.095  |proj g|=      0.013292
# At iterate    23  f =      -78.095  |proj g|=       0.35477
# At iterate    24  f =      -78.095  |proj g|=    0.00047192
# At iterate    25  f =      -78.095  |proj g|=    5.5344e-05
#
# iterations 25
# function evaluations 33
# segments explored during Cauchy searches 26
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 5.53437e-05
# final function value -78.0947
#
# F = -78.0947
# final  value -78.094746
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  63.38222
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -63.382  |proj g|=       1.4812
# At iterate     1  f =       -67.09  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -67.0904
#
# F = -67.0904
# final  value -67.090371
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  52.076
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -52.076  |proj g|=      0.39228
# At iterate     1  f =      -70.191  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -70.1907
#
# F = -70.1907
# final  value -70.190665
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  52.73186
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -52.732  |proj g|=      0.52878
# At iterate     1  f =      -73.396  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -73.3957
#
# F = -73.3957
# final  value -73.395713
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  75.19761
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -75.198  |proj g|=      0.77534
# At iterate     1  f =      -76.418  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -76.4177
#
# F = -76.4177
# final  value -76.417702
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  50.09524
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -50.095  |proj g|=      0.68378
# At iterate     1  f =      -79.278  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -79.2779
#
# F = -79.2779
# final  value -79.277864
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  68.39517
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -68.395  |proj g|=      0.47258
# At iterate     1  f =      -81.928  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -81.928
#
# F = -81.928
# final  value -81.928014
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  67.68135
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -67.681  |proj g|=       1.4173
# At iterate     1  f =      -84.227  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -84.2272
#
# F = -84.2272
# final  value -84.227247
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  86.76107
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -86.761  |proj g|=      0.48574
# At iterate     1  f =      -87.431  |proj g|=       0.43351
# At iterate     2  f =      -87.766  |proj g|=       0.31316
# At iterate     3  f =      -87.782  |proj g|=       0.33135
# At iterate     4  f =      -87.782  |proj g|=       0.36354
# At iterate     5  f =      -87.782  |proj g|=       0.36355
# At iterate     6  f =      -87.782  |proj g|=       0.36356
# At iterate     7  f =      -87.783  |proj g|=       0.36358
# At iterate     8  f =      -87.785  |proj g|=       0.36362
# At iterate     9  f =       -87.79  |proj g|=       0.36368
# At iterate    10  f =      -87.804  |proj g|=       0.36379
# At iterate    11  f =       -87.84  |proj g|=       0.36398
# At iterate    12  f =      -87.953  |proj g|=       0.38706
# At iterate    13  f =      -91.087  |proj g|=       0.47645
# At iterate    14  f =      -91.165  |proj g|=       0.44948
# At iterate    15  f =      -92.141  |proj g|=       0.36691
# At iterate    16  f =      -92.713  |proj g|=       0.36672
# At iterate    17  f =      -92.824  |proj g|=      0.025388
# At iterate    18  f =      -92.829  |proj g|=      0.023691
# At iterate    19  f =      -92.829  |proj g|=        0.3667
# At iterate    20  f =      -92.829  |proj g|=      0.030732
#
# iterations 20
# function evaluations 35
# segments explored during Cauchy searches 21
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 0.030732
# final function value -92.8286
#
# F = -92.8286
# final  value -92.828605
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  35.31548
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -35.315  |proj g|=       1.3132
# At iterate     1  f =      -88.029  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -88.029
#
# F = -88.029
# final  value -88.028975
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  76.25767
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -76.258  |proj g|=      0.58573
# At iterate     1  f =      -91.041  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -91.0411
#
# F = -91.0411
# final  value -91.041131
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  71.60968
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       -71.61  |proj g|=     0.095974
# At iterate     1  f =      -92.274  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -92.2736
#
# F = -92.2736
# final  value -92.273578
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  46.83898
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -46.839  |proj g|=       2.6931
# At iterate     1  f =      -95.127  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 3
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0
# final function value -95.1275
#
# F = -95.1275
# final  value -95.127481
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 166 86
#   - best initial criterion value(s) :  69.47193
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -69.472  |proj g|=      0.18457
# At iterate     1  f =      -98.246  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -98.2461
#
# F = -98.2461
# final  value -98.246097
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 170 86
#   - best initial criterion value(s) :  31.82386
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -31.824  |proj g|=      0.24179
# At iterate     1  f =      -101.41  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -101.408
#
# F = -101.408
# final  value -101.407669
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 170 86
#   - best initial criterion value(s) :  80.52722
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -80.527  |proj g|=      0.25751
# At iterate     1  f =      -104.57  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -104.574
#
# F = -104.574
# final  value -104.574115
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 170 86
#   - best initial criterion value(s) :  63.55651
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -63.557  |proj g|=      0.16881
# At iterate     1  f =      -107.72  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -107.716
#
# F = -107.716
# final  value -107.716360
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 170 86
#   - best initial criterion value(s) :  116.2552
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -116.26  |proj g|=      0.36369
# At iterate     1  f =      -116.59  |proj g|=        0.1338
# At iterate     2  f =      -116.98  |proj g|=       0.15066
# At iterate     3  f =      -117.01  |proj g|=       0.35975
# At iterate     4  f =      -117.01  |proj g|=       0.15498
# At iterate     5  f =      -117.01  |proj g|=       0.15504
# At iterate     6  f =      -117.01  |proj g|=       0.15506
# At iterate     7  f =      -117.01  |proj g|=       0.35952
# At iterate     8  f =      -117.01  |proj g|=       0.35953
# At iterate     9  f =      -117.01  |proj g|=       0.35955
# At iterate    10  f =      -117.01  |proj g|=       0.35958
# At iterate    11  f =      -117.01  |proj g|=       0.35963
# At iterate    12  f =      -117.01  |proj g|=       0.35972
# At iterate    13  f =      -117.02  |proj g|=       0.35986
# At iterate    14  f =      -117.02  |proj g|=       0.36008
# At iterate    15  f =      -117.05  |proj g|=        0.3604
# At iterate    16  f =       -117.1  |proj g|=       0.36077
# At iterate    17  f =      -117.18  |proj g|=       0.36086
# At iterate    18  f =      -117.24  |proj g|=      0.031906
# At iterate    19  f =      -117.25  |proj g|=     0.0086503
# At iterate    20  f =      -117.25  |proj g|=      0.026782
# At iterate    21  f =      -117.25  |proj g|=     0.0028116
# At iterate    22  f =      -117.25  |proj g|=    0.00017846
#
# iterations 22
# function evaluations 27
# segments explored during Cauchy searches 23
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 0
# norm of the final projected gradient 0.00017846
# final function value -117.253
#
# F = -117.253
# final  value -117.253121
# converged
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10
#   - parameters upper bounds :  0.3680389 170 86
#   - best initial criterion value(s) :  67.11377
#
# N = 3, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=      -67.114  |proj g|=      0.20056
# At iterate     1  f =       -112.8  |proj g|=             0
#
# iterations 1
# function evaluations 2
# segments explored during Cauchy searches 2
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 0
# final function value -112.801
#
# F = -112.801
# final  value -112.801425
# converged
# Error in auc(test$Class, yhat): could not find function "auc"
# Traceback:
#
# 1. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "could not find function \"auc\"", base::quote(auc(test$Class,
#  .     yhat)))
